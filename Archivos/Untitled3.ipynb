# %%
import pandas as pd
import matplotlib.pyplot as mpl

# %%
tlv = pd.read_csv("C:/Users/manuell/Videos/CienciaDatos_AN/televisa.csv")

# %%
tlv.columns
# Out:
# Index(['Date', 'TLEVISACPO.MX', 'Unnamed: 2'], dtype='object')

# %%
x = tlv['Date']
y = tlv['TLEVISACPO.MX']

# %%
grafico = mpl.figure()
ejes = grafico.add_axes([0,0,1,1])
ejes.plot(x,y, label = 'TLVS', marker='.')
ejes.set_ylabel('Precio')
ejes.set_title('Precio Acciones Mensual')
ejes.legend()
