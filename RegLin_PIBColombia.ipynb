# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# Definir los datos manualmente en listas
Year = [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
        2021, 2022]

# %%
PIBperCapita = [2595.54, 2236.07, 2546.85, 2465.00, 2421.16, 2305.17, 2811.45, 3448.53, 3782.60, 4762.08, 5534.68, 5245.95, 
6392.75, 7392.94, 8096.80, 8263.64, 8167.47, 6228.65, 5936.26, 6449.97, 6782.03, 6436.50, 5304.28, 6182.70, 6630.28]

# %%
GastoEducacion = [3.92, 4.44, 3.51, 3.70, 4.26, 4.32, 4.07, 4.02, 3.91, 4.08, 
3.93, 4.77, 4.83, 4.46, 4.37, 4.87, 4.62, 4.47, 4.47, 4.53, 4.44, 4.51, 5.26, None, None]

# %%
# Crear el DataFrame con los datos
df = pd.DataFrame({'Year': Year, 'PIBperCapita': PIBperCapita, 'GastoEducacion': GastoEducacion})

# %%
df.head()
# Out:
#    Year  PIBperCapita  GastoEducacion
# 0  1998       2595.54            3.92
# 1  1999       2236.07            4.44
# 2  2000       2546.85            3.51
# 3  2001       2465.00            3.70
# 4  2002       2421.16            4.26

# %%
df.isnull().sum()
# Out:
# Year              0
# PIBperCapita      0
# GastoEducacion    0
# dtype: int64

# %%
df.dropna(subset=['GastoEducacion'], inplace=True)

# %%
modelo = LinearRegression()

# %%
x = df[['GastoEducacion']]

# %%
y = df[['PIBperCapita']]

# %%
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
intercep = modelo.intercept_

# %%
coef = modelo.coef_[0]

# %%
print(f" Interceptor: {intercep} \n Coeficiente: {coef}")
# Out:
#  Interceptor: [-8253.41105907]
#  Coeficiente: [3061.69631474]
