# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Simulación simple
np.random.seed(0)
area = np.random.normal(100, 20, 100)
habitaciones = area / 20 + np.random.normal(0, 0.5, 100)
precio = 50000 + (area * 300) + np.random.normal(0, 10000, 100)

# %%
df = pd.DataFrame({
    "area": area,
    "habitaciones": habitaciones,
    "precio": precio
})

# %%
df.head()
# Out:
#          area  habitaciones        precio
# 0  135.281047      7.705628  86892.495696
# 1  108.003144      4.726278  80007.151474
# 2  119.574760      5.343495  96869.023864
# 3  144.817864      7.725592  99997.996502
# 4  137.351160      6.280996  97606.663202

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlación entre variables")
plt.show()
